# %%
import pandas as pd
import numpy as np
from pprint import pprint as pp

from Pstage_03_KLUE_Relation_extraction.load_data import *

# %%
dataset = load_data('/opt/ml/input/data/train/train.tsv')

# %%
k_dataset = pd.read_csv('/opt/ml/input/data/train/kaist.tsv', delimiter='\t', header=None)

# %%
dataset.head()
# Out:
#                                             sentence entity_01  entity_02  \
# 0  영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)...      랜드로버        자동차
# 1  선거에서 민주당은 해산 전 의석인 230석에 한참 못 미치는 57석(지역구 27석,...       민주당        27석
# 2  유럽 축구 연맹(UEFA) 집행위원회는 2014년 1월 24일에 열린 회의를 통해 ...  유럽 축구 연맹       UEFA
# 3  용병 공격수 챠디의 부진과 시즌 초 활약한 강수일의 침체, 시즌 중반에 영입한 세르...       강수일        공격수
# 4  람캄행 왕은 1237년에서 1247년 사이 수코타이의 왕 퍼쿤 씨 인트라팃과 쓰엉 ...       람캄행  퍼쿤 씨 인트라팃
#
#    label
# 0     17
# 1      0
# 2      6
# 3      2
# 4      8

# %%
k_dataset
# Out:
#                0                1        2  \
# 0            민주당  mainlyLocatedIn       미국
# 1          지미_카터           bornIn    조지아_주
# 2          지미_카터         placedIn    조지아_주
# 3          지미_카터        locatedIn    조지아_주
# 4        안와르_사다트           diedIn      이집트
# ...          ...              ...      ...
# 985571      홋카이도              NaN       일본
# 985572     개그콘서트              NaN  KBS_2TV
# 985573       댄싱9              NaN     Mnet
# 985574  TV쇼_진품명품              NaN  KBS_1TV
# 985575  칠전팔기_구해라              NaN     Mnet
#
#                                                         3
# 0       제임스 얼 ' 지미 ' 카터 주니어 ( , 1924 년 10 월_1 일 ~ ) 는 ...
# 1                지미_카터 는 조지아_주 섬터 카운티 플레인스 마을 에서 태어났 다 .
# 2                지미_카터 는 조지아_주 섬터 카운티 플레인스 마을 에서 태어났 다 .
# 3                지미_카터 는 조지아_주 섬터 카운티 플레인스 마을 에서 태어났 다 .
# 4       카터 는 이집트 와 이스라엘 을 조정 하 여 , 캠프 데이비드 에서 안와르_사다트 ...
# ...                                                   ...
# ...

# %%
k_label = list(k_dataset[1].unique())

# %%
with open('/opt/ml/input/data/label_type.pkl', 'rb') as f:
    label_type = pickle.load(f)
original_label = list(label_type.keys())

# %%
pp(k_label)
# Out:
# ['mainlyLocatedIn',
#  'bornIn',
#  'placedIn',
#  'locatedIn',
#  'diedIn',
#  'nationality',
#  'president',
#  'activity',
#  'member',
#  'commander',
#  'field',
#  'influence',
#  'religion',
#  'employer',
#  'leader',
#  'job',
#  'endedOn',
#  'startedIn',
#  'influencedBy',
#  'teacher',
#  'majorWork',
#  'combatant',
#  'education',
#  'buriedIn',
#  'genre',
#  'capital',
#  'owner',
#  'manager',
#  'director',
#  'happenedIn',
#  'producer',
#  'startedOn',
#  'artist',
#  'channel',
#  'creator',
#  'language',
#  'type',
#  'user',
#  'spouse',
#  'parent',
#  'player',
#  'relatedLocation',
#  'relative',
#  'composer',
#  'child',
#  'ideology',
#  'distributor',
#  'city',
#  nan,
#  'position',
#  'previous',
#  'product',
#  'currentMember',
#  'belongsTo',
#  'publisher',
#  'broader',
#  'party',
#  'representative',
#  'platform',
#  'resident',
#  'author',
#  'awarded',
#  'related',
#  'next',
#  'vicePresident',
#  'operatingSystem',
#  'composedOf',
# ...

# %%
pp(original_label)
# Out:
# ['관계_없음',
#  '인물:배우자',
#  '인물:직업/직함',
#  '단체:모회사',
#  '인물:소속단체',
#  '인물:동료',
#  '단체:별칭',
#  '인물:출신성분/국적',
#  '인물:부모님',
#  '단체:본사_국가',
#  '단체:구성원',
#  '인물:기타_친족',
#  '단체:창립자',
#  '단체:주주',
#  '인물:사망_일시',
#  '단체:상위_단체',
#  '단체:본사_주(도)',
#  '단체:제작',
#  '인물:사망_원인',
#  '인물:출생_도시',
#  '단체:본사_도시',
#  '인물:자녀',
#  '인물:제작',
#  '단체:하위_단체',
#  '인물:별칭',
#  '인물:형제/자매/남매',
#  '인물:출생_국가',
#  '인물:출생_일시',
#  '단체:구성원_수',
#  '단체:자회사',
#  '인물:거주_주(도)',
#  '단체:해산일',
#  '인물:거주_도시',
#  '단체:창립일',
#  '인물:종교',
#  '인물:거주_국가',
#  '인물:용의자',
#  '인물:사망_도시',
#  '단체:정치/종교성향',
#  '인물:학교',
#  '인물:사망_국가',
#  '인물:나이']

# %%
def load_data(dataset_dir):
    with open('/opt/ml/input/data/label_type.pkl', 'rb') as f:
        label_type = pickle.load(f)
    dataset = pd.read_csv(dataset_dir, delimiter='\t', header=None)
    dataset = preprocessing_dataset(dataset, label_type)
    return dataset

def preprocessing_dataset(dataset, label_type):
    label = []
    for i in dataset[8]:
        if i == 'blind':
            label.append(100)
        else:
            label.append(label_type[i])
    out_dataset = pd.DataFrame({'sentence':dataset[1],'entity_01':dataset[2],'entity_02':dataset[5],'label':label,})
    return out_dataset

# %% [markdown]
# ## **진행 순서**
# 1. label 바꾸기
# 2. _를 빈칸으로 바꾸기
# 3. 형식 맞추기

# %% [markdown]
# ## **1. 인물:사망_국가, 인물:사망_도시**

# %% [markdown]
# > diedIn에 사망 국가와 사망 도시가 혼합되어 있어서 분리해줘야 함

# %%
country = """가나
가봉
가이아나
감비아
과테말라
그레나다
그리스
기니
기니비사우
나고르노카라바흐 공화국
나미비아
나우루
나이지리아
남수단
남아프리카 공화국
남오세티야
네덜란드
네팔
노르웨이
뉴질랜드
니제르
니카라과
대한민국
덴마크
도미니카
도미니카 공화국
독일
동티모르
라오스
라이베리아
라트비아
러시아
레바논
레소토
루마니아
룩셈부르크
르완다
리비아
리투아니아
리히텐슈타인
마다가스카르
마셜 제도
마케도니아 공화국
말라위
말레이시아
말리
멕시코
모나코
모로코
모리셔스
모리타니
모잠비크
몬테네그로
몰도바
몰디브
몰타
몽골
미국
미얀마
미크로네시아 연방
바누아투
바레인
바베이도스
바티칸 시국
바하마
방글라데시
베냉
베네수엘라
베트남
벨기에
벨라루스
벨리즈
보스니아 헤르체고비나
보츠와나
볼리비아
부룬디
부르키나파소
부탄
북키프로스
불가리아
브라질
브루나이
사모아
사우디아라비아
사하라 아랍 민주 공화국
산마리노
상투메 프린시페
세네갈
세르비아
세이셸
세인트루시아
세인트빈센트 그레나딘
세인트키츠 네비스
소말리아
소말릴란드
솔로몬 제도
수단
수리남
스리랑카
스와질란드
스웨덴
스위스
스페인
슬로바키아
슬로베니아
시리아
시에라리온
싱가포르
아랍에미리트
아르메니아
아르헨티나
아이슬란드
아이티
아일랜드
아제르바이잔
아프가니스탄
안도라
알바니아
알제리
압하스
앙골라
앤티가 바부다
에리트레아
에스토니아
에콰도르
에티오피아
엘살바도르
영국
예멘
오만
오스트레일리아
오스트리아
온두라스
요르단
우간다
우루과이
우즈베키스탄
우크라이나
이라크
이란
이스라엘
이집트
이탈리아
인도
인도네시아
일본
자메이카
잠비아
적도 기니
조선민주주의인민공화국
조지아
중앙아프리카 공화국
중화민국
중화인민공화국
지부티
짐바브웨
차드
체코
칠레
카메룬
카보베르데
카자흐스탄
카타르
캄보디아
캐나다
케냐
코모로
코소보 공화국
코스타리카
코트디부아르
콜롬비아
콩고 공화국
콩고 민주 공화국
쿠바
쿠웨이트
크로아티아
키르기스스탄
키리바시
키프로스
타지키스탄
탄자니아
태국
터키
토고
통가
투르크메니스탄
투발루
튀니지
트란스니스트리아
트리니다드 토바고
파나마
파라과이
파키스탄
파푸아뉴기니
팔라우
팔레스타인
페루
포르투갈
폴란드
프랑스
피지
핀란드
필리핀
헝가리"""

# %%
country_list = "|".join(country.split("\n"))

# %%
print(country_list)
# Out:
# 가나|가봉|가이아나|감비아|과테말라|그레나다|그리스|기니|기니비사우|나고르노카라바흐 공화국|나미비아|나우루|나이지리아|남수단|남아프리카 공화국|남오세티야|네덜란드|네팔|노르웨이|뉴질랜드|니제르|니카라과|대한민국|덴마크|도미니카|도미니카 공화국|독일|동티모르|라오스|라이베리아|라트비아|러시아|레바논|레소토|루마니아|룩셈부르크|르완다|리비아|리투아니아|리히텐슈타인|마다가스카르|마셜 제도|마케도니아 공화국|말라위|말레이시아|말리|멕시코|모나코|모로코|모리셔스|모리타니|모잠비크|몬테네그로|몰도바|몰디브|몰타|몽골|미국|미얀마|미크로네시아 연방|바누아투|바레인|바베이도스|바티칸 시국|바하마|방글라데시|베냉|베네수엘라|베트남|벨기에|벨라루스|벨리즈|보스니아 헤르체고비나|보츠와나|볼리비아|부룬디|부르키나파소|부탄|북키프로스|불가리아|브라질|브루나이|사모아|사우디아라비아|사하라 아랍 민주 공화국|산마리노|상투메 프린시페|세네갈|세르비아|세이셸|세인트루시아|세인트빈센트 그레나딘|세인트키츠 네비스|소말리아|소말릴란드|솔로몬 제도|수단|수리남|스리랑카|스와질란드|스웨덴|스위스|스페인|슬로바키아|슬로베니아|시리아|시에라리온|싱가포르|아랍에미리트|아르메니아|아르헨티나|아이슬란드|아이티|아일랜드|아제르바이잔|아프가니스탄|안도라|알바니아|알제리|압하스|앙골라|앤티가 바부다|에리트레아|에스토니아|에콰도르|에티오피아|엘살바도르|영국|예멘|오만|오스트레일리아|오스트리아|온두라스|요르단|우간다|우루과이|우즈베키스탄|우크라이나|이라크|이란|이스라엘|이집트|이탈리아|인도|인도네시아|일본|자메이카|잠비아|적도 기니|조선민주주의인민공화국|조지아|중앙아프리카 공화국|중화민국|중화인민공화국|지부티|짐바브웨|차드|체코|칠레|카메룬|카보베르데|카자흐스탄|카타르|캄보디아|캐나다|케냐|코모로|코소보 공화국|코스타리카|코트디부아르|콜롬비아|콩고 공화국|콩고 민주 공화국|쿠바|쿠웨이트|크로아티아|키르기스스탄|키리바시|키프로스|타지키스탄|탄자니아|태국|터키|토고|통가|투르크메니스탄|투발루|튀니지|트란스니스트리아|
# ...

# %%
diedIn = k_dataset.loc[k_dataset[1]=='diedIn']

# %%
diedIn_country = diedIn[diedIn[2].str.contains(country_list)]

# %%
diedIn_country.head()
# Out:
#            0       1            2  \
# 4    안와르_사다트  diedIn          이집트
# 10    메나헴_베긴  diedIn         이스라엘
# 71       함석헌  diedIn         대한민국
# 91       백남준  diedIn           미국
# 113      김정일  diedIn  조선민주주의인민공화국
#
#                                                      3
# 4    카터 는 이집트 와 이스라엘 을 조정 하 여 , 캠프 데이비드 에서 안와르_사다트 ...
# 10   카터 는 이집트 와 이스라엘 을 조정 하 여 , 캠프 데이비드 에서 안와르_사다트 ...
# 71    함석헌 ( 咸錫憲 , 1901 년 3 월_13 일 ~ 1989 년 2 월_4 일 ...
# 91    백남준 ( 白南準 , , 1932 년 7 월_20 일 ~ 2006 년 1 월_29...
# 113  8 월_23 일 - 김정일 조선민주주의인민공화국 국방 위원장 과 블라디미르_푸틴 러...

# %%
diedIn_country[2].unique()
# Out:
# array(['이집트', '이스라엘', '대한민국', '미국', '조선민주주의인민공화국', '영국', '독일_민주_공화국',
#        '독일', '중화민국', '인도', '오스트리아', '체코슬로바키아', '라트비아_소비에트_사회주의_공화국',
#        '스페인', '일본', '네덜란드', '스위스', '프랑스', '아르헨티나', '이라크', '중화인민공화국',
#        '가나자와_시', '인도네시아', '러시아', '일본_제국', '그리스', '노르웨이', '나이지리아', '대콜롬비아',
#        '필리핀', '사우디아라비아', '투르크메니스탄', '이란', '러시아_제국', '싱가포르', '파키스탄',
#        '이탈리아', '체코', '터키', '쿠바', '베트남_민주_공화국', '우즈베키스탄', '칠레', '몽골',
#        '잠비아', '베트남', '덴마크', '콜롬비아', '캐나다', '오스트리아_제국', '베트남_공화국', '케냐',
#        '가나안', '멕시코', '독일_제국', '슬로베니아', '핀란드', '스웨덴', '벨기에', '말레이시아',
#        '가이아나', '이탈리아_왕국', '나치_독일', '아프가니스탄', '라오스', '시리아', '포르투갈', '아일랜드',
#        '알바니아', '볼리비아', '크로아티아_왕국', '폴란드', '캄보디아', '튀니지', '오스트리아-헝가리_제국',
#        '그레이트브리튼_아일랜드_연합왕국', '아이슬란드', '방글라데시', '오스트리아_대공국', '프랑스_제1공화국',
#        '엘살바도르', '브라질', '루마니아', '에스토니아', '페루', '통가', '라이베리아', '헝가리',
#        '아일랜드_자유국', '타지키스탄', '세인트루시아', '파나마', '조지아_주', '뉴질랜드', '모나코',
# ...

# %% [markdown]
# **순서 맞추기 & _를 공백으로 치환**

# %%
diedIn_country_dict = {'sentence': list(diedIn_country[3].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_01': list(diedIn_country[0].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_02': list(diedIn_country[2].str.split('_').apply(lambda str: ' '.join(str))), 
                       'label':[40]*len(diedIn_country)}

# %%
diedIn_country_df = pd.DataFrame(diedIn_country_dict)

# %% [markdown]
# **중복 제거**

# %%
diedIn_country_df = diedIn_country_df.drop_duplicates()

# %%
diedIn_country_df.to_csv(os.path.join("/opt/ml/input/data/train/kaist", "40_dienIn_country.tsv"), sep = '\t', index=False)

# %% [markdown]
# ### **인물:사망_도시**

# %%
diedIn_city = diedIn[~diedIn[2].str.contains(country_list)]

# %%
diedIn_city[2].unique()
# Out:
# array(['경상남도', '서울특별시', '홍콩', '소련', '투쿰스', '뮌헨', '괴팅겐', '위', '수나라',
#        '타이베이_시', '조선', '이스탄불', '로마_제국', '바젤', '서울아산병원', '명나라', '콜카타',
#        '종로구', '안국동', '경교장', '도쿄', '런던', '하이델베르크', '베를린', '코펜하겐', '즈시_시',
#        '장성군', '고창군', '전라북도', '부안면', '고려', '팔공산', '신라', '만주', '하얼빈_역',
#        '바이에른_왕국', '서경', '로마', '루앙', '태평천국', '블라디보스토크', '평양직할시', '동대문구',
#        '텍사스_주', '정통_칼리파조', '빈', '뉴욕', '무굴_제국', '남아프리카_공화국', '오스만_제국',
#        '청나라', '덕수궁', '알렉산드리아', '전한', '메디나', '마드리드', '백령도', '잉글랜드', '중국',
#        '스몰렌스크', '모스크바', '쓰시마_섬', '오장원', '대한제국', '시라쿠사', '새남터', '파리',
#        '일제_강점기', '버지니아_주', '마포구', '당나라', '하노이', '베이징_시', '진나라', '타이완',
#        '호놀룰루', '궁정동', '프라하', '예루살렘', '신성_로마_제국', '유고슬라비아_사회주의_연방공화국',
#        '노르망디', '그린란드', '한성부', '두만강', '파주시', '동부여', '달마티아', '나라_시', '라벤나',
#        '국군수도병원', '콘스탄티노폴리스', '쾰른', '아테네', '촉한', '샹양_시', '밀라노', '놀라',
#        '에페소스', '강변북로', '용산구', '후금', '셸란_섬', '거문도', '오와리_국', '장안', '백제',
# ...

# %% [markdown]
# **이걸 합리적으로 거르는 건 너무 힘들 거 같으니 우선 ~시로 끝나는 것만 살려두자**

# %%
diedIn_city = diedIn_city[diedIn_city[2].str.contains("시")][~diedIn_city[2].str.contains("스타디움")]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
diedIn_city
# Out:
#               0       1        2  \
# 538         김수환  diedIn    서울특별시
# 774         장제스  diedIn   타이베이_시
# 2147        김도연  diedIn    서울특별시
# 2195        윤보선  diedIn    서울특별시
# 2196         허정  diedIn    서울특별시
# ...         ...     ...      ...
# 813706  다리우스_3세  diedIn  페르시아_제국
# 815333      김일성  diedIn    평양직할시
# 944840      강석원  diedIn    광주광역시
# 959991      여운형  diedIn    서울특별시
# 974134      장덕수  diedIn    서울특별시
#
#                                                         3
# 538     대통령 후보 시절 인 2002 년 6 월_20 일 에 서울특별시 종로구 혜화동 가톨...
# 774     한편 중국_국민당 은 장제스 의 지도하 에 현재 의 타이베이_시 로 정부 를 이전 ...
# 2147    6 월 김형근 ( 金亨根 ) 대한민국_내무부 의 서울특별시 판자 집 철거 정책 에 ...
# 2195    1963 년 3 월 박정희 가 군정 연장 안 을 발표 하 자 , 윤보선 과 허정 은...
# 2196    1963 년 3 월 박정희 가 군정 연장 안 을 발표 하 자 , 윤보선 과 허정 은...
# ...                                                   ...
# 813706  로도스 의_멤논 ( 기원전 380 년 – 333 년 ) , 페르시아_제국 의 다리우...
# 815333  2012 년 3 월 26 일 에 는 평양직할시 에 위치 한 김일성 주석 의 생가 인...
# ...

# %%
diedIn_city[2].unique()
# Out:
# array(['서울특별시', '타이베이_시', '즈시_시', '평양직할시', '쓰시마_섬', '시라쿠사', '베이징_시',
#        '파주시', '나라_시', '샹양_시', '바티칸_시국', '이시카와_현', '선양_시', '테네시_주', '순천시',
#        '창원시', '샌프란시스코', '아시시', '가고시마_시', '취푸_시', '시즈오카_시', '미시간_주', '시애틀',
#        '시칠리아', '몬테카시노', '시카고', '개성특급시', '히로시마_시', '요코스카_시', '교토_시',
#        '뤄양_시', '안동시', '안성시', '오쓰_시', '대구광역시', '청더_시', '이천시', '나가사키_시',
#        '안산시', '하얼빈_시', '영주시', '부산광역시', '광한_시', '김천시', '페르시아_제국', '진주시',
#        '시에나', '경주시', '강릉시', '안달루시아_지방', '카시노', '후시미_성', '펑화_시', '아우스트라시아',
#        '제주시', '논산시', '가고시마_현', '마산시', '수원시', '셴양_시', '시칠리아_왕국', '충주시',
#        '양시칠리아_왕국', '스미요시_행궁', '시베리아', '아마시아', '상하이_시', '톈진_시', '발렌시아',
#        '군기시', '요시다_고리_산성', '전주시', '구레_시', '낭시', '삼척시', '인천광역시', '성남시',
#        '쯔보_시', '크테시폰', '공주시', '통영시', '솔트레이크시티', '트빌리시', '호찌민_시', '클리시',
#        '징저우_시', '마쓰모토_시', '양저우_시', '카이펑_시', '이케다_시', '난조_시', '고양시',
#        '후쿠오카_시', '허페이_시', '양산시', '오사카_시', '청두_시', '항저우_시', '양주시', '과천시',
# ...

# %%
diedIn_city_dict = {'sentence': list(diedIn_city[3].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_01': list(diedIn_city[0].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_02': list(diedIn_city[2].str.split('_').apply(lambda str: ' '.join(str))), 
                       'label':[37]*len(diedIn_city)}

# %%
diedIn_city_df = pd.DataFrame(diedIn_city_dict)
diedIn_city_df = diedIn_city_df.drop_duplicates()

# %%
diedIn_city_df.to_csv(os.path.join("/opt/ml/input/data/train/kaist", "37_dienIn_city.tsv"), sep = '\t', index=False)

# %% [markdown]
# ### **2. label 만들기: 인물:출생_국가, 인물:출생_도시**

# %%
bornIn = k_dataset.loc[k_dataset[1]=='bornIn']

# %%
bornIn_country = bornIn[bornIn[2].str.contains(country_list)]

# %%
bornIn_country[2].unique()
# Out:
# array(['조지아_주', '영국', '러시아', '대한민국', '중화인민공화국', '일본', '인도', '조선민주주의인민공화국',
#        '네덜란드', '스위스', '독일', '케냐', '아르헨티나', '이라크', '이란', '헝가리', '이탈리아',
#        '프랑스', '아일랜드', '미국', '러시아_제국', '인도네시아', '덴마크', '일본_제국', '브라질',
#        '스페인', '벨기에', '캐나다', '그리스', '필리핀', '노르웨이', '폴란드', '나이지리아', '중화민국',
#        '미얀마', '사우디아라비아', '오스트레일리아', '루마니아', '베네수엘라', '싱가포르', '멕시코', '스웨덴',
#        '우즈베키스탄', '칠레', '앙골라', '이집트', '페루', '오스트리아', '터키', '코트디부아르',
#        '룩셈부르크', '베트남', '고대_그리스', '오스트리아-헝가리_제국', '알제리', '몽골', '콜롬비아',
#        '크로아티아', '세르비아', '핀란드', '말레이시아', '이스라엘', '이탈리아_왕국', '자메이카', '페르가나',
#        '아프가니스탄', '네팔', '뉴질랜드', '라오스', '라트비아', '시리아', '모잠비크', '바베이도스',
#        '세네갈', '아제르바이잔', '알바니아', '키프로스', '캄보디아', '튀니지', '아이티', '에콰도르',
#        '켄터키_주', '브라질_제국', '그레이트브리튼_아일랜드_연합왕국', '과테말라', '도미니카_공화국', '몰디브',
#        '볼리비아', '아이슬란드', '오스트리아_대공국', '독일_민주_공화국', '엘살바도르', '불가리아', '팔라우',
#        '포르투갈', '방글라데시', '체코', '체코슬로바키아', '에스토니아', '파키스탄', '수단', '토고',
# ...

# %%
bornIn_country_dict = {'sentence': list(bornIn_country[3].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_01': list(bornIn_country[0].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_02': list(bornIn_country[2].str.split('_').apply(lambda str: ' '.join(str))), 
                       'label':[26]*len(bornIn_country)}

bornIn_country_df = pd.DataFrame(bornIn_country_dict)
bornIn_country_df = bornIn_country_df.drop_duplicates()
bornIn_country_df.to_csv(os.path.join("/opt/ml/input/data/train/kaist", "26_bornIn_country.tsv"), sep = '\t', index=False)

# %%
bornIn_city = bornIn[~bornIn[2].str.contains(country_list)]

# %%
list(bornIn_city[2].unique())
# Out:
# ['평안북도',
#  '뤼베크',
#  '랑엔브로이히',
#  '쾰른',
#  '부산광역시',
#  '홍콩',
#  '페르시아_제국',
#  '상트페테르부르크',
#  '소련',
#  '스코틀랜드',
#  '스톡홀름',
#  '평양직할시',
#  '고려',
#  '오스만_제국',
#  '송',
#  '바젤',
#  '통천군',
#  '강원도',
#  '버크셔_주',
#  '나이로비',
#  '아칸소_주',
#  '명나라',
#  '윈난_성',
#  '조선',
#  '대한제국',
#  '아산시',
#  '충청남도',
#  '전라북도',
#  '한성부',
#  '도쿄',
#  '잔지바르',
#  '코펜하겐',
#  '보스턴',
#  '매사추세츠_주',
#  '도쿄_부',
#  '리우데자네이루',
#  '장성군',
#  '전라남도',
#  '부안면',
#  '고창군',
#  '히카리_시',
#  '야마구치_현',
#  '구마게_군',
#  '스오_국',
#  '춘천시',
#  '상하이_시',
#  '포츠머스',
#  '제노바',
#  '시애틀',
#  '워싱턴_주',
#  '문정동',
#  '해주군',
#  '황해도',
#  '바이에른_왕국',
#  '서경',
#  '의령군',
#  '카르타고',
#  '콘스탄티노폴리스',
#  '메카',
#  '무굴_제국',
#  '미주리_주',
#  '청나라',
#  '알렉산드리아',
#  '전한',
#  '탕가니카',
#  '중국',
#  '서울특별시',
#  '라벤나',
#  '버지니아_주',
#  '봉하마을',
#  '런던',
#  '지다',
#  '울산군',
#  '경상남도',
#  '뉴욕',
#  '예루살렘',
#  '파리',
#  '샌프란시스코',
#  '링컨셔_주',
#  '보스니아_헤르체고비나',
#  '부여군',
#  '바르샤바',
#  '그리니치',
#  '프라하',
#  '이사우리아',
#  '경상북도',
#  '신용동',
#  '공산면',
#  '대구광역시',
#  '마케도니아_왕국',
# ...

# %%
bornIn_city_dict = {'sentence': list(bornIn_city[3].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_01': list(bornIn_city[0].str.split('_').apply(lambda str: ' '.join(str))), 
                       'entity_02': list(bornIn_city[2].str.split('_').apply(lambda str: ' '.join(str))), 
                       'label':[19]*len(bornIn_city)}

bornIn_city_df = pd.DataFrame(bornIn_city_dict)
bornIn_city_df = bornIn_city_df.drop_duplicates()
bornIn_city_df.to_csv(os.path.join("/opt/ml/input/data/train/kaist", "19_bornIn_city.tsv") , sep = '\t', index=False)
